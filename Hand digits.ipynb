# %%
from sklearn.datasets import load_digits
from keras_preprocessing import image
import matplotlib.pyplot as plt
import cv2
import numpy as np

datasets = load_digits()
fig = plt.figure(figsize=(12, 6))

columns = 5#int(input("Column = "))
row = 2#int(input("Row = "))
index = 0
dataValue = 0
images = np.array()
label = []
for i in range(1,row+1):
    for j in range(1, columns+1):
        img = datasets.images[index]
        fig.add_subplot(row, columns, index+1)
        plt.imshow(img)
        index = index+1
        images.
        label.append(dataValue)
        dataValue = dataValue + 1
        if dataValue == 10:
            dataValue = 0
plt.show()
print(images[0])
# Out:
# [[ 0.  0.  5. 13.  9.  1.  0.  0.]
#  [ 0.  0. 13. 15. 10. 15.  5.  0.]
#  [ 0.  3. 15.  2.  0. 11.  8.  0.]
#  [ 0.  4. 12.  0.  0.  8.  8.  0.]
#  [ 0.  5.  8.  0.  0.  9.  8.  0.]
#  [ 0.  4. 11.  0.  1. 12.  7.  0.]
#  [ 0.  2. 14.  5. 10. 12.  0.  0.]
#  [ 0.  0.  6. 13. 10.  0.  0.  0.]]
